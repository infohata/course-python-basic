# %%
from bs4 import BeautifulSoup

# %%
html = """
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <title>First HTML Page</title>
</head>
<body>
  <div id="first">
    <h3 data-example="yes">hi</h3>
    <p>more text.</p>
  </div>
  <ol>
    <li class="special">This list item is special.</li>
    <li class="special">This list item is also special.</li>
    <li>This list item is not special.</li>
  </ol>
  <div data-example="yes">bye</div>
</body>
</html>
"""

# %%
soup = BeautifulSoup(html, "html.parser")
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.body.p)
# Out:
# <p>more text.</p>

# %%
print(soup.find_all('div'))
# Out:
# [<div id="first">
# <h3 data-example="yes">hi</h3>
# <p>more text.</p>
# </div>, <div data-example="yes">bye</div>]

# %%
print(soup.find_all(class_='special'))
# Out:
# [<li class="special">This list item is special.</li>, <li class="special">This list item is also special.</li>]

# %%
print(soup.find_all(attrs={'data-example': 'yes'}))
# Out:
# [<h3 data-example="yes">hi</h3>, <div data-example="yes">bye</div>]

# %%
print(soup.select('#first'))
# Out:
# [<div id="first">
# <h3 data-example="yes">hi</h3>
# <p>more text.</p>
# </div>]

# %%
print(soup.select('.special'))
# Out:
# [<li class="special">This list item is special.</li>, <li class="special">This list item is also special.</li>]

# %%
print(soup.select('ol li'))
# Out:
# [<li class="special">This list item is special.</li>, <li class="special">This list item is also special.</li>, <li>This list item is not special.</li>]

# %%
print(soup.select('[data-example]'))
# Out:
# [<h3 data-example="yes">hi</h3>, <div data-example="yes">bye</div>]

# %%
stuff = soup.select('ol li')
for li in stuff:
    print(li.get_text())
# Out:
# This list item is special.
# This list item is also special.
# This list item is not special.

# %%
stuff = soup.select('.special')
stuff[0].get_text()
# Out:
# 'This list item is special.'

# %%
for element in stuff:
    print(element.name, ':', element.get_text())
# Out:
# li : This list item is special.
# li : This list item is also special.

# %%
for element in stuff:
    print(f'{element.name} with attributes {element.attrs} contains text: {element.get_text()}')
# Out:
# li with attributes {'class': ['special']} contains text: This list item is special.
# li with attributes {'class': ['special']} contains text: This list item is also special.

# %%
soup.select('#first')[0].attrs['id']
# Out:
# 'first'

# %%
soup.body.contents
# Out:
# ['\n',
#  <div id="first">
#  <h3 data-example="yes">hi</h3>
#  <p>more text.</p>
#  </div>,
#  '\n',
#  <ol>
#  <li class="special">This list item is special.</li>
#  <li class="special">This list item is also special.</li>
#  <li>This list item is not special.</li>
#  </ol>,
#  '\n',
#  <div data-example="yes">bye</div>,
#  '\n']

# %%
listas = soup.body.ol
listas
# Out:
# <ol>
# <li class="special">This list item is special.</li>
# <li class="special">This list item is also special.</li>
# <li>This list item is not special.</li>
# </ol>

# %%
from bs4.element import Tag

for item in listas.children:
    if type(item) == Tag:
        print(item)
# Out:
# <li class="special">This list item is special.</li>
# <li class="special">This list item is also special.</li>
# <li>This list item is not special.</li>

# %%
item.parent.parent
# Out:
# <body>
# <div id="first">
# <h3 data-example="yes">hi</h3>
# <p>more text.</p>
# </div>
# <ol>
# <li class="special">This list item is special.</li>
# <li class="special">This list item is also special.</li>
# <li>This list item is not special.</li>
# </ol>
# <div data-example="yes">bye</div>
# </body>

# %%
pirmas_li = soup.find('li')
print(pirmas_li)
print(li.find_next_sibling())
print(li.find_next_siblings())
# Out:
# <li class="special">This list item is special.</li>
# <li>This list item is not special.</li>
# [<li>This list item is not special.</li>]

# %%
import requests
html = requests.get('https://www.aic.lt/ispardavimas').content

# %%
aic_sales_page = BeautifulSoup(html, "html.parser")
print(aic_sales_page)
# Out:
# <!DOCTYPE html>
#
# <html lang="lt">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <title>Sumažinta kaina</title>
# <script data-keepinline="true">
#     var ajaxGetProductUrl = '//www.aic.lt/modulis/cdc_googletagmanager/async';
#     var ajaxShippingEvent = 1;
#     var ajaxPaymentEvent = 1;
#
# /* datalayer */
# dataLayer = window.dataLayer || [];
#     let cdcDatalayer = {"pageCategory":"pricesdrop","event":null,"ecommerce":{"currency":"EUR"}};
#     dataLayer.push(cdcDatalayer);
#
# /* call to GTM Tag */
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-M75MWG');
#
# /* async call to avoid cache system for dynamic data */
# var cdcgtmreq = new XMLHttpRequest();
# cdcgtmreq.onreadystatechange = function() {
#     if (cdcgtmreq.readyState == XMLHttpRequest.DONE ) {
#         if (cdcgtmreq.status == 200) {
#           	var datalayerJs = cdcgtmreq.responseText;
#             try {
#                 var datalayerObj = JSON.parse(datalayerJs);
#                 dataLayer = dataLayer || [];
#                 dataLayer.push(datalayerObj);
#             } catch(e) {
#                console.log("[CDCGTM] error while parsing json");
#             }
#
#                     }
#         dataLayer.push({
#           'event': 'datalayer_ready'
#         });
#     }
# };
# cdcgtmreq.open("GET", "//www.aic.lt/modulis/cdc_googletagmanager/async?action=user" /*+ "?" + new Date().getTime()*/, true);
# cdcgtmreq.setRequestHeader('X-Requested-With', 'XMLHttpRequest');
# cdcgtmreq.send();
# </script>
# <meta content="Our special products" name="description"/>
# <meta content="" name="keywords"/>
# <link href="https://www.aic.lt/en/prices-drop" hreflang="en-us" rel="alternate"/>
# <link href="https://www.aic.lt/ispardavimas" hreflang="lt-lt" rel="alternate"/>
# <meta content="Sumažinta kaina" property="og:title">
# <meta content="Our special products" property="og:description">
# <meta content="website" property="og:type">
# <meta content="https://www.aic.lt/ispardavimas" property="og:url">
# <meta content="ARMIJAI IR CIVILIAMS" property="og:site_name"/>
# <meta content="https://www.aic.lthttps://www.aic.lt/img/logo-16684396091.jpg" property="og:image"/>
# <script type="application/ld+json">
# {
#     "@context" : "http://schema.org",
#     "@type" : "Organization",
#     "name" : "ARMIJAI IR CIVILIAMS",
#     "url" : "https://www.aic.lt/",
#     "logo" : {
#         "@type":"ImageObject",
#         "url":"https://www.aic.lthttps://www.aic.lt/img/logo-16684396091.jpg"
#     }
# }
#
# </script>
# <script type="application/ld+json">
# {
#     "@context":"http://schema.org",
#     "@type":"WebPage",
#     "isPartOf": {
#         "@type":"WebSite",
#         "url":  "https://www.aic.lt/",
#         "name": "ARMIJAI IR CIVILIAMS"
#     },
#     "name": "Sumažinta kaina",
#     "url":  "https://www.aic.lt/ispardavimas"
# }
#
#
# </script>
# <script type="application/ld+json">
#     {
#     "@context": "https://schema.org",
#     "@type": "BreadcrumbList",
#     "itemListElement": [
#         {
#     "@type": "ListItem",
#     "position": 1,
#     "name": "Pradžia",
#     "item": "https://www.aic.lt/"
#     },        {
#     "@type": "ListItem",
#     "position": 2,
#     "name": "Sumažinta kaina",
#     "item": "https://www.aic.lt/ispardavimas"
#     }    ]
#     }
#     </script>
# <link href="?page=2" rel="next"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://www.aic.lt/img/favicon-1.ico?1668439609" rel="icon" type="image/vnd.microsoft.icon"/>
# <link href="https://www.aic.lt/img/favicon-1.ico?1668439609" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://www.aic.lt/themes/classic-rocket/assets/cache/theme-f6eba096.css" media="all" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#         var af_ajax_path = "https:\/\/www.aic.lt\/modulis\/amazzingfilter\/ajax?ajax=1";
#         var af_classes = {"load_font":1,"icon-filter":"icon-filter","u-times":"u-times","icon-eraser":"icon-eraser","icon-lock":"icon-lock","icon-unlock-alt":"icon-unlock-alt","icon-minus":"icon-minus","icon-plus":"icon-plus","icon-check":"icon-check","icon-save":"icon-save","js-product-miniature":"js-product-miniature","pagination":"pagination"};
#         var af_ids = {"main":"main"};
#         var af_is_modern = 1;
#         var af_product_count_text = "";
#         var af_product_list_class = "af-product-list";
#         var current_controller = "pricesdrop";
#         var jolisearch = {"amb_joli_search_action":"https:\/\/www.aic.lt\/jolisearch","amb_joli_search_link":"https:\/\/www.aic.lt\/jolisearch","amb_joli_search_controller":"jolisearch","blocksearch_type":"top","show_cat_desc":0,"ga_acc":0,"id_lang":2,"url_rewriting":1,"use_autocomplete":1,"minwordlen":3,"l_products":"Prek\u0117s","l_manufacturers":"Manufacturers","l_categories":"Kategorijos","l_no_results_found":"Nieko nerasta","l_more_results":"Daugiau rezultat\u0173 \u00bb","ENT_QUOTES":3,"search_ssl":true,"self":"\/home\/aic\/domains\/aic.lt\/public_html\/modules\/ambjolisearch","position":{"my":"right top","at":"right bottom","collision":"flipfit none"},"classes":"ps17","display_manufacturer":"","display_category":""};
#         var lgcookieslaw_block = false;
#         var lgcookieslaw_cookie_name = "__lglawaic";
#         var lgcookieslaw_position = "2";
#         var lgcookieslaw_reload = false;
#         var lgcookieslaw_session_time = "31536000";
#         var load_more = false;
#         var page_link_rewrite_text = "page";
#         var prestashop = {"cart":{"products":[],"totals":{"total":{"type":"total","label":"I\u0161 viso","amount":0,"value":"0,00\u00a0\u20ac"},"total_including_tax":{"type":"total","label":"Viso (su PVM)","amount":0,"value":"0,00\u00a0\u20ac"},"total_excluding_tax":{"type":"total","label":"Viso (be PVM)","amount":0,"value":"0,00\u00a0\u20ac"}},"subtotals":{"products":{"type":"products","label":"Tarpin\u0117 suma","amount":0,"value":"0,00\u00a0\u20ac"},"discounts":null,"shipping":{"type":"shipping","label":"Pristatymas","amount":0,"value":0},"tax":null},"products_count":0,"summary_string":"0 preki\u0173","vouchers":{"allowed":1,"added":[]},"discounts":[],"minimalPurchase":0,"minimalPurchaseRequired":""},"currency":{"id":1,"name":"Euras","iso_code":"EUR","iso_code_num":"978","sign":"\u20ac"},"customer":{"lastname":null,"firstname":null,"email":null,"birthday":null,"newsletter":null,"newsletter_date_add":null,"optin":null,"website":null,"company":null,"siret":null,"ape":null,"is_logged":false,"gender":{"type":null,"name":null},"addresses":[]},"language":{"name":"lietuvi\u0173 kalba (Lithuanian)","iso_code":"lt","locale":"lt-LT","language_code":"lt-lt","is_rtl":"0","date_format_lite":"Y-m-d","date_format_full":"Y-m-d H:i:s","id":2},"page":{"title":"","canonical":null,"meta":{"title":"Suma\u017einta kaina","description":"Our special products","keywords":"","robots":"index"},"page_name":"prices-drop","body_classes":{"lang-lt":true,"lang-rtl":false,"country-IT":true,"currency-EUR":true,"layout-left-column":true,"page-prices-drop":true,"tax-display-enabled":true},"admin_notifications":[]},"shop":{"name":"ARMIJAI IR CIVILIAMS","logo":"https:\/\/www.aic.lt\/img\/logo-16684396091.jpg","stores_icon":"https:\/\/www.aic.lt\/img\/logo_stores.png","favicon":"https:\/\/www.aic.lt\/img\/favicon-1.ico"},"urls":{"base_url":"https:\/\/www.aic.lt\/","current_url":"https:\/\/www.aic.lt\/ispardavimas","shop_domain_url":"https:\/\/www.aic.lt","img_ps_url":"https:\/\/www.aic.lt\/img\/","img_cat_url":"https:\/\/www.aic.lt\/img\/c\/","img_lang_url":"https:\/\/www.aic.lt\/img\/l\/","img_prod_url":"https:\/\/www.aic.lt\/img\/p\/","img_manu_url":"https:\/\/www.aic.lt\/img\/m\/","img_sup_url":"https:\/\/www.aic.lt\/img\/su\/","img_ship_url":"https:\/\/www.aic.lt\/img\/s\/","img_store_url":"https:\/\/www.aic.lt\/img\/st\/","img_col_url":"https:\/\/www.aic.lt\/img\/co\/","img_url":"https:\/\/www.aic.lt\/themes\/classic-rocket\/assets\/img\/","css_url":"https:\/\/www.aic.lt\/themes\/classic-rocket\/assets\/css\/","js_url":"https:\/\/www.aic.lt\/themes\/classic-rocket\/assets\/js\/","pic_url":"https:\/\/www.aic.lt\/upload\/","pages":{"address":"https:\/\/www.aic.lt\/adresas","addresses":"https:\/\/www.aic.lt\/adresai","authentication":"https:\/\/www.aic.lt\/prisijungimas","cart":"https:\/\/www.aic.lt\/krepselis","category":"https:\/\/www.aic.lt\/index.php?controller=category","cms":"https:\/\/www.aic.lt\/index.php?controller=cms","contact":"https:\/\/www.aic.lt\/susisiekite-su-mumis","discount":"https:\/\/www.aic.lt\/nuolaida","guest_tracking":"https:\/\/www.aic.lt\/svecio-paskyra","history":"https:\/\/www.aic.lt\/uzsakymu-istorija","identity":"https:\/\/www.aic.lt\/asmenine-informacija","index":"https:\/\/www.aic.lt\/","my_account":"https:\/\/www.aic.lt\/mano-paskyra","order_confirmation":"https:\/\/www.aic.lt\/uzsakymo-patvirtinimas","order_detail":"https:\/\/www.aic.lt\/index.php?controller=order-detail","order_follow":"https:\/\/www.aic.lt\/uzsakymo-sekimas","order":"https:\/\/www.aic.lt\/uzsakymas","order_return":"https:\/\/www.aic.lt\/index.php?controller=order-return","order_slip":"https:\/\/www.aic.lt\/prekiu-grazinimai","pagenotfound":"https:\/\/www.aic.lt\/puslapis-nerastas","password":"https:\/\/www.aic.lt\/slaptazodzio-atkurimas","pdf_invoice":"https:\/\/www.aic.lt\/index.php?controller=pdf-invoice","pdf_order_return":"https:\/\/www.aic.lt\/index.php?controller=pdf-order-return","pdf_order_slip":"https:\/\/www.aic.lt\/index.php?controller=pdf-order- ...
#         var prestashopFacebookAjaxController = "https:\/\/www.aic.lt\/modulis\/ps_facebook\/Ajax";
#         var psr_icon_color = "#F19D76";
#         var show_load_more_btn = true;
#       </script>
# <meta content="128433fe4b7a6681f2fb0cea87bf5d7a" name="verify-paysera"/>
# <script type="text/javascript">
# 	(window.gaDevIds=window.gaDevIds||[]).push('d6YPbH');
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#             ga('create', 'UA-34174408-3', 'auto');
#                         ga('send', 'pageview');
#
#     ga('require', 'ec');
# </script>
# <style type="text/css">@media(max-width:767px){#amazzing_filter{position:fixed;opacity:0;}}</style>
# </meta></meta></meta></meta></head>
# <body class="lang-lt country-it currency-eur layout-left-column page-prices-drop tax-display-enabled" id="prices-drop">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-M75MWG" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <main>
# <header class="l-header" id="header">
# <div class="header-banner">
# </div>
# <div class="header-nav">
# <div class="header__container container">
# <div class="u-a-i-c d--flex-between visible--desktop">
# <div class="small">
# </div>
# <div class="header-nav__right">
# </div>
# </div>
# </div>
# </div>
# <div class="container header-top d--flex-between u-a-i-c">
# <a class="header__logo header-top__col" href="https://www.aic.lt/">
# <img alt="ARMIJAI IR CIVILIAMS" class="logo img-fluid" src="https://www.aic.lt/img/logo-16684396091.jpg"/>
# </a>
# <div class="header__right header-top__col">
# <a class="visible--desktop link-page-stores" href="../../parduotuves">
#                 Parduotuvių kontaktai
#                 <i class="material-icons blockcart__icon">location_on</i>
# </a>
# <div class="visible--desktop header-search-wrapper">
# <!-- Block search module TOP -->
# <form action="//www.aic.lt/paieska" class="search-widget" data-search-controller-url="//www.aic.lt/paieska" data-search-widget="" method="get">
# <input name="controller" type="hidden" value="search"/>
# <div class="search-widget__group">
# <input aria-label="Paieška" class="form-control search-widget__input-right" name="s" placeholder="Prekės paieška" type="text" value=""/>
# <button class="search-widget__btn btn btn-link" type="submit">
# <i class="material-icons search"></i>
# <span class="d-none">Paieška</span>
# </button>
# </div>
# </form>
# <!-- /Block search module TOP -->
# </div>
# <div id="_desktop_language_selector">
# <div class="language-selector-wrapper">
# <div class="language-selector dropdown js-dropdown">
# <button aria-expanded="false" aria-haspopup="true" aria-label="Kalbos" class="btn btn-sm dropdown-toggle language-select-btn" data-toggle="dropdown">
# <img alt="lietuvių kalba" height="18" src="https://www.aic.lt/img/flags/lt.jpg" width="28"/>
# </button>
# <div aria-labelledby="language-selector-label" class="dropdown-menu">
# <a class="dropdown-item small" data-iso-code="en" href="https://www.aic.lt/en/prices-drop">
# <img alt="English" height="12" src="https://www.aic.lt/img/flags/gb.jpg" width="22"/>
#                 en
#               </a>
# <a class="dropdown-item small active" data-iso-code="lt" href="https://www.aic.lt/ispardavimas">
# <img alt="lietuvių kalba" height="12" src="https://www.aic.lt/img/flags/lt.jpg" width="22"/>
#                 lt
#               </a>
# </div>
# </div>
# </div>
# </div>
# <div class="user-info header__rightitem">
# <a class="u-link-body" href="https://www.aic.lt/mano-paskyra" rel="nofollow" title="Prisijunkite prie savo kliento paskyros">
# <span><i class="material-icons"></i></span>
# </a>
# </div>
# <div>
# <div class="blockcart cart-preview header__rightitem inactive" data-product-count="0" data-refresh-url="//www.aic.lt/modulis/ps_shoppingcart/ajax">
# <div class="shopping-cart-wrapper">
# <div class="shopping-cart">
# <a class="u-link-body" href="//www.aic.lt/krepselis?action=show" rel="nofollow">
# <span><i class="material-icons blockcart__icon">shopping_cart</i></span>
# <span class="cart-products-count small blockcart__count d-none">(0)</span>
# </a>
# </div>
# <div class="cart-preview-body">
# <ul>
# </ul>
# <div id="cart-preview-amounts-container">
# <div class="cart-subtotals">
# <div>
# <span>Tarpinė suma:</span>
# <span class="value" id="cart-preview-subtotal-value">0,00 €</span>
# </div>
# </div>
# <div class="cart-total" id="cart-preview-total">
# <span class="label">Iš viso:</span>
# <span class="value" id="cart-preview-total-value">0,00 €</span>
# </div>
# <div id="cart-preview-add-to-cart">
# <a class="btn btn-primary" href="//www.aic.lt/krepselis?action=show" id="cart-preview-add-to-cart-button" type="button">Žiūrėti krepšelį</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
#
# <div class="container header-menu__container">
# <nav class="menu visible--desktop" id="_desktop_top_menu">
# <ul class="menu-top h-100" data-depth="0" id="top-menu" role="navigation">
# <li aria-controls="top_sub_menu_41070" aria-expanded="false" aria-haspopup="true" aria-owns="top_sub_menu_41070" class="h-100 menu__item--0 category menu__item menu__item--top" id="category-2">
# <div class="menu__item-header">
# <span class="menu__item-link--0 d-md-flex menu__item-link--top w-100 h-100" data-depth="0" id="menu__item-link--0">
#                             Prekių kategorijos                            <i class="material-icons visible--desktop d-lg-flex align-items-lg-end align-self-center">
#                                 expand_more                            </i>
# </span>
# <span class="visible--mobile mobile-menu-icon">
# <span class="d-block navbar-toggler icon-collapse" data-target="#top_sub_menu_46773" data-toggle="collapse">
# <i class="material-icons menu__collapseicon">chevron_right</i>
# </span>
# </span>
# </div>
# <div aria-expanded="false" aria-hidden="true" aria-labelledby="category-2" class="menu-sub clearfix collapse show" data-collapse-hide-mobile="" id="top_sub_menu_46773" role="group">
# <div class="menu-sub__content ignore-container">
# <ul class="menu-sub__list menu-sub__list--1 flex-column" data-depth="1">
# <li aria-controls="top_sub_menu_16839" aria-expanded="false" aria-haspopup="true" aria-owns="top_sub_menu_16839" class="menu__item--1 category menu__item menu__item--sub" id="category-8">
# <div class="menu__item-header">
# <a class="menu__item-link--1 d-md-flex menu__item-link--sub" data-depth="1" href="https://www.aic.lt/8-apranga" id="menu__item-link--1">
#                         Apranga                            <i class="material-icons visible--desktop">
#                                 chevron_right                            </i>
# </a>
# <span class="visible--mobile mobile-menu-icon">
# <span class="d-block navbar-toggler icon-collapse" data-target="#top_sub_menu_9367" data-toggle="collapse">
# <i class="material-icons menu__collapseicon">chevron_right</i>
# </span>
# </span>
# </div>
# <div aria-expanded="false" aria-hidden="true" aria-labelledby="category-8" class="clearfix collapse show" data-collapse-hide-mobile="" id="top_sub_menu_9367" role="group">
# <div>
# <ul class="menu-sub__list menu-sub__list--2 flex-column" data-depth="2">
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-129">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/129-striukes" id="menu__item-link--2">
#                         Striukės                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-177">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/177-neperslampami-rubai" id="menu__item-link--2">
#                         Neperšlampami rūbai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-11">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/11-dzemperiai-megztiniai" id="menu__item-link--2">
#                         Džemperiai, megztiniai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-40">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/40-svarkai" id="menu__item-link--2">
#                         Švarkai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-41">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/41-kelnes" id="menu__item-link--2">
#                         Kelnės                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-44">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/44-liemenes" id="menu__item-link--2">
#                         Liemenės                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-45">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/45-marskiniai" id="menu__item-link--2">
#                         Marškiniai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-46">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/46-trumparankoviai-marskineliai" id="menu__item-link--2">
#                         Trumparankoviai marškinėliai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-47">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/47-silti-apatiniai-drabuziai" id="menu__item-link--2">
#                         Šilti apatiniai drabužiai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-43">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/43-sortai" id="menu__item-link--2">
#                         Šortai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li aria-controls="top_sub_menu_50229" aria-expanded="false" aria-haspopup="true" aria-owns="top_sub_menu_50229" class="menu__item--2 category menu__item menu__item--sub" id="category-48">
# <div class="menu__item-header">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/48-galvos-apdangalai" id="menu__item-link--2">
#                         Galvos apdangalai                            <i class="material-icons visible--desktop">
#                                 chevron_right                            </i>
# </a>
# <span class="visible--mobile mobile-menu-icon">
# <span class="d-block navbar-toggler icon-collapse" data-target="#top_sub_menu_68331" data-toggle="collapse">
# <i class="material-icons menu__collapseicon">chevron_right</i>
# </span>
# </span>
# </div>
# <div aria-expanded="false" aria-hidden="true" aria-labelledby="category-48" class="clearfix collapse show" data-collapse-hide-mobile="" id="top_sub_menu_68331" role="group">
# <div>
# <ul class="menu-sub__list menu-sub__list--3 flex-column" data-depth="3">
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-123">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/123-kepures-su-snapeliu" id="menu__item-link--3">
#                         Kepurės su snapeliu                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-164">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/164-vasarines-kepures" id="menu__item-link--3">
#                         Vasarinės kepurės                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-124">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/124-ziemines-kepures" id="menu__item-link--3">
#                         Žieminės kepurės                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-125">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/125-kaukes" id="menu__item-link--3">
#                         Kaukės                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-126">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/126-beretes" id="menu__item-link--3">
#                         Beretės                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-127">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/127-tinkliukai-nuo-vabzdziu" id="menu__item-link--3">
#                         Tinkliukai nuo vabzdžių                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-128">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/128-salikai-ir-skareles" id="menu__item-link--3">
#                         Šalikai ir skarelės                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-176">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/176-salmai" id="menu__item-link--3">
#                         Šalmai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li aria-controls="top_sub_menu_21995" aria-expanded="false" aria-haspopup="true" aria-owns="top_sub_menu_21995" class="menu__item--2 category menu__item menu__item--sub" id="category-49">
# <div class="menu__item-header">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/49-pirstines" id="menu__item-link--2">
#                         Pirštinės                            <i class="material-icons visible--desktop">
#                                 chevron_right                            </i>
# </a>
# <span class="visible--mobile mobile-menu-icon">
# <span class="d-block navbar-toggler icon-collapse" data-target="#top_sub_menu_99578" data-toggle="collapse">
# <i class="material-icons menu__collapseicon">chevron_right</i>
# </span>
# </span>
# </div>
# <div aria-expanded="false" aria-hidden="true" aria-labelledby="category-49" class="clearfix collapse show" data-collapse-hide-mobile="" id="top_sub_menu_99578" role="group">
# <div>
# <ul class="menu-sub__list menu-sub__list--3 flex-column" data-depth="3">
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-165">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/165-ziemines-pirstines" id="menu__item-link--3">
#                         Žieminės pirštinės                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-166">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/166-taktines-pirstines" id="menu__item-link--3">
#                         Taktinės pirštinės                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-167">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/167-zveju-ir-medziotoju-pirstines" id="menu__item-link--3">
#                         Žvejų ir medžiotojų pirštinės                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-168">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/168-laipiojimo-ir-sporto-pirstines" id="menu__item-link--3">
#                         Laipiojimo ir sporto pirštinės                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-169">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/169-kitos-pirstines" id="menu__item-link--3">
#                         Kitos pirštinės                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-50">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/50-kojines" id="menu__item-link--2">
#                         Kojinės                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-175">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/175-spec-apranga" id="menu__item-link--2">
#                         Spec. apranga                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-51">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/51-vaikiska-apranga" id="menu__item-link--2">
#                         Vaikiška apranga                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-304">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/304-apranga-moterims" id="menu__item-link--2">
#                         Apranga moterims                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li aria-controls="top_sub_menu_19884" aria-expanded="false" aria-haspopup="true" aria-owns="top_sub_menu_19884" class="menu__item--1 category menu__item menu__item--sub" id="category-9">
# <div class="menu__item-header">
# <a class="menu__item-link--1 d-md-flex menu__item-link--sub" data-depth="1" href="https://www.aic.lt/9-avalyne" id="menu__item-link--1">
#                         Avalynė                            <i class="material-icons visible--desktop">
#                                 chevron_right                            </i>
# </a>
# <span class="visible--mobile mobile-menu-icon">
# <span class="d-block navbar-toggler icon-collapse" data-target="#top_sub_menu_66726" data-toggle="collapse">
# <i class="material-icons menu__collapseicon">chevron_right</i>
# </span>
# </span>
# </div>
# <div aria-expanded="false" aria-hidden="true" aria-labelledby="category-9" class="clearfix collapse show" data-collapse-hide-mobile="" id="top_sub_menu_66726" role="group">
# <div>
# <ul class="menu-sub__list menu-sub__list--2 flex-column" data-depth="2">
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-13">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/13-kariski-batai" id="menu__item-link--2">
#                         Kariški batai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-15">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/15-taktiniai-batai" id="menu__item-link--2">
#                         Taktiniai batai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-158">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/158-medziotoju-batai" id="menu__item-link--2">
#                         Medžiotojų batai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-179">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/179-turistiniai-batai-zygiams" id="menu__item-link--2">
#                         Turistiniai batai žygiams                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-36">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/36-kasdienine-miesto-avalyne" id="menu__item-link--2">
#                         Kasdieninė miesto avalynė                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-139">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/139-sportine-avalyne" id="menu__item-link--2">
#                         Sportinė avalynė                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-17">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/17-darbiniai-batai" id="menu__item-link--2">
#                         Darbiniai batai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-16">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/16-paramilitariniai-kerzai" id="menu__item-link--2">
#                         Paramilitariniai kerzai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-18">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/18-guminiai-ir-pvc-batai" id="menu__item-link--2">
#                         Guminiai ir PVC batai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-19">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/19-sandalai" id="menu__item-link--2">
#                         Sandalai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-37">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/37-vandens-avalyne" id="menu__item-link--2">
#                         Vandens avalynė                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-138">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/138-antbaciai-blauzdines" id="menu__item-link--2">
#                         Antbačiai, blauzdinės                             <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-20">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/20-avalynes-aksesuarai" id="menu__item-link--2">
#                         Avalynės aksesuarai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li aria-controls="top_sub_menu_58934" aria-expanded="false" aria-haspopup="true" aria-owns="top_sub_menu_58934" class="menu__item--1 category menu__item menu__item--sub" id="category-3">
# <div class="menu__item-header">
# <a class="menu__item-link--1 d-md-flex menu__item-link--sub" data-depth="1" href="https://www.aic.lt/3-ekipuote" id="menu__item-link--1">
#                         Ekipuotė                            <i class="material-icons visible--desktop">
#                                 chevron_right                            </i>
# </a>
# <span class="visible--mobile mobile-menu-icon">
# <span class="d-block navbar-toggler icon-collapse" data-target="#top_sub_menu_32735" data-toggle="collapse">
# <i class="material-icons menu__collapseicon">chevron_right</i>
# </span>
# </span>
# </div>
# <div aria-expanded="false" aria-hidden="true" aria-labelledby="category-3" class="clearfix collapse show" data-collapse-hide-mobile="" id="top_sub_menu_32735" role="group">
# <div>
# <ul class="menu-sub__list menu-sub__list--2 flex-column" data-depth="2">
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-118">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/118-taktines-liemenes" id="menu__item-link--2">
#                         Taktinės liemenės                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li aria-controls="top_sub_menu_96606" aria-expanded="false" aria-haspopup="true" aria-owns="top_sub_menu_96606" class="menu__item--2 category menu__item menu__item--sub" id="category-378">
# <div class="menu__item-header">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/378-kuno-apsaugos-priemones" id="menu__item-link--2">
#                         Kūno apsaugos priemonės                            <i class="material-icons visible--desktop">
#                                 chevron_right                            </i>
# </a>
# <span class="visible--mobile mobile-menu-icon">
# <span class="d-block navbar-toggler icon-collapse" data-target="#top_sub_menu_34512" data-toggle="collapse">
# <i class="material-icons menu__collapseicon">chevron_right</i>
# </span>
# </span>
# </div>
# <div aria-expanded="false" aria-hidden="true" aria-labelledby="category-378" class="clearfix collapse show" data-collapse-hide-mobile="" id="top_sub_menu_34512" role="group">
# <div>
# <ul class="menu-sub__list menu-sub__list--3 flex-column" data-depth="3">
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-21">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/21-koju-keliu-ir-alkuniu-apsaugos" id="menu__item-link--3">
#                         Kojų kelių ir alkūnių apsaugos                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-5">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/5-apsauginiai-akiniai" id="menu__item-link--3">
#                         Apsauginiai akiniai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-379">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/379-kvepavimo-apsauga-" id="menu__item-link--3">
#                         Kvėpavimo apsauga                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-7">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/7-klausos-apsauga" id="menu__item-link--3">
#                         Klausos apsauga                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-380">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/380-balistine-apsauga-" id="menu__item-link--3">
#                         Balistinė apsauga                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-132">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/132-dirzai-petnesos" id="menu__item-link--2">
#                         Diržai, petnešos                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li aria-controls="top_sub_menu_32751" aria-expanded="false" aria-haspopup="true" aria-owns="top_sub_menu_32751" class="menu__item--2 category menu__item menu__item--sub" id="category-300">
# <div class="menu__item-header">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/300-ekipuotes-ir-ginklu-deklai" id="menu__item-link--2">
#                         Ekipuotės ir ginklų dėklai                            <i class="material-icons visible--desktop">
#                                 chevron_right                            </i>
# </a>
# <span class="visible--mobile mobile-menu-icon">
# <span class="d-block navbar-toggler icon-collapse" data-target="#top_sub_menu_1341" data-toggle="collapse">
# <i class="material-icons menu__collapseicon">chevron_right</i>
# </span>
# </span>
# </div>
# <div aria-expanded="false" aria-hidden="true" aria-labelledby="category-300" class="clearfix collapse show" data-collapse-hide-mobile="" id="top_sub_menu_1341" role="group">
# <div>
# <ul class="menu-sub__list menu-sub__list--3 flex-column" data-depth="3">
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-159">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/159-ivairus-ekipuotes-deklai" id="menu__item-link--3">
#                         Įvairūs ekipuotės dėklai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-133">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/133-saudmenu-detuviu-deklai" id="menu__item-link--3">
#                         Šaudmenų dėtuvių dėklai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-157">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/157-ginklu-deklai" id="menu__item-link--3">
#                         Ginklų dėklai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-131">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/131-pistoletu-deklai" id="menu__item-link--3">
#                         Pistoletų dėklai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-38">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/38-antrankiu-ir-kitu-specpriemoniu-deklai" id="menu__item-link--3">
#                         Antrankių ir kitų spec.priemonių dėklai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-52">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/52-maskuotes-reikmenys" id="menu__item-link--2">
#                         Maskuotės reikmenys                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-136">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/136-isgyvenimo-reikmenys" id="menu__item-link--2">
#                         Išgyvenimo reikmenys                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-14">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/14-kompasai" id="menu__item-link--2">
#                         Kompasai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li aria-controls="top_sub_menu_87247" aria-expanded="false" aria-haspopup="true" aria-owns="top_sub_menu_87247" class="menu__item--2 category menu__item menu__item--sub" id="category-53">
# <div class="menu__item-header">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/53-kitas-smulkus-inventorius" id="menu__item-link--2">
#                         Kitas smulkus inventorius                            <i class="material-icons visible--desktop">
#                                 chevron_right                            </i>
# </a>
# <span class="visible--mobile mobile-menu-icon">
# <span class="d-block navbar-toggler icon-collapse" data-target="#top_sub_menu_60567" data-toggle="collapse">
# <i class="material-icons menu__collapseicon">chevron_right</i>
# </span>
# </span>
# </div>
# <div aria-expanded="false" aria-hidden="true" aria-labelledby="category-53" class="clearfix collapse show" data-collapse-hide-mobile="" id="top_sub_menu_60567" role="group">
# <div>
# <ul class="menu-sub__list menu-sub__list--3 flex-column" data-depth="3">
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-143">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/143-ivairus-laikikliai-karabinai" id="menu__item-link--3">
#                         Įvairūs laikikliai, karabinai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-146">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/146-virvutes-sagteles" id="menu__item-link--3">
#                         Virvutės, sagtelės                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-147">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/147-ziebtuveliai-degtukai-iziebejai" id="menu__item-link--3">
#                         Žiebtuvėliai, degtukai, įžiebėjai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-148">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/148-ranku-sildytuvai" id="menu__item-link--3">
#                         Rankų šildytuvai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-149">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/149-uzrasu-knygutes-rasikliai" id="menu__item-link--3">
#                         Užrašų knygutės, rašikliai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-151">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/151-ginklu-valymo-reikmenys" id="menu__item-link--3">
#                         Ginklų valymo reikmenys                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--3 category menu__item menu__item--sub" id="category-152">
# <a class="menu__item-link--3" data-depth="3" href="https://www.aic.lt/152-kitos-smulkmenos" id="menu__item-link--3">
#                         Kitos smulkmenos                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-10">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/10-laipiojimo-iranga" id="menu__item-link--2">
#                         Laipiojimo įranga                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-134">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/134-specekipuote-ir-iranga" id="menu__item-link--2">
#                         Spec.ekipuotė ir įranga                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-135">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/135-treniruociu-iranga" id="menu__item-link--2">
#                         Treniruočių įranga                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li aria-controls="top_sub_menu_9032" aria-expanded="false" aria-haspopup="true" aria-owns="top_sub_menu_9032" class="menu__item--1 category menu__item menu__item--sub" id="category-25">
# <div class="menu__item-header">
# <a class="menu__item-link--1 d-md-flex menu__item-link--sub" data-depth="1" href="https://www.aic.lt/25-irankiai" id="menu__item-link--1">
#                         Įrankiai                            <i class="material-icons visible--desktop">
#                                 chevron_right                            </i>
# </a>
# <span class="visible--mobile mobile-menu-icon">
# <span class="d-block navbar-toggler icon-collapse" data-target="#top_sub_menu_43492" data-toggle="collapse">
# <i class="material-icons menu__collapseicon">chevron_right</i>
# </span>
# </span>
# </div>
# <div aria-expanded="false" aria-hidden="true" aria-labelledby="category-25" class="clearfix collapse show" data-collapse-hide-mobile="" id="top_sub_menu_43492" role="group">
# <div>
# <ul class="menu-sub__list menu-sub__list--2 flex-column" data-depth="2">
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-156">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/156-peiliai" id="menu__item-link--2">
#                         Peiliai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-144">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/144-kiseniniai-peiliai" id="menu__item-link--2">
#                         Kišeniniai peiliai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-137">
# <a class="menu__item-link--2" data-depth="2" href="https://www.aic.lt/137-daugiafunkciniai-peiliai-ir-irankiai" id="menu__item-link--2">
#                         Daugiafunkciniai peiliai ir įrankiai                            <i class="material-icons visible--desktop">
# </i>
# </a>
# </li>
# <li class="menu__item--2 category menu__item menu__item--sub" id="category-73">
# ...
#             }
#         });
#     </script>
# <div class="lgcookieslaw-banner lgcookieslaw-reject-all-button-enabled" id="lgcookieslaw_banner">
# <div class="cookies-container">
# <div class="lgcookieslaw-message">
# <p class="MsoNormal"><span lang="LT" style="font-family: 'Helvetica',sans-serif; color: black; mso-themecolor: text1;">Siekiant pagerinti Jūsų naršymo kokybę, statistiniais bei vidinės rinkodaros tikslais šioje svetainėje yra naudojami slapukai, kuriuos Jūs galite bet kada išjungti.</span> <span style="font-size: 10.0pt; line-height: 107%; font-family: 'Arial',sans-serif; color: #818076; mso-ansi-language: EN-US;"><o:p></o:p></span></p> <a href="https://www.aic.lt/informacija/43-privatumo-politika" id="lgcookieslaw_info" target="_blank">
#                 Daugiau informacijos
#             </a>
# </div>
# <div class="lgcookieslaw-button-container">
# <button class="btn lgcookieslaw-btn lgcookieslaw-reject-all lgcookieslaw-link-button" id="lgcookieslaw_reject_all" onclick="closeinfo(true, 0)">
#                     Atmesti
#                 </button>
# <button class="btn lgcookieslaw-btn lgcookieslaw-accept lggoogleanalytics-accept" id="lgcookieslaw_accept" onclick="closeinfo(true, 1)">Priimti</button>
# </div>
# </div>
# </div>
# <div class="lgcookieslaw-modal" id="lgcookieslaw_modal">
# <div class="lgcookieslaw-modal-body">
# <h2>Slapukų konfigūracija</h2>
# <div class="lgcookieslaw-section">
# <div class="lgcookieslaw-section-name">
#                         Functional cookies <small>(techniniai)</small> </div>
# <div class="lgcookieslaw-section-checkbox">
# <label class="lgcookieslaw-switch">
# <div class="lgcookieslaw-slider-option-left">Ne</div>
# <input checked="checked" class="lgcookieslaw-purpose-enabled" data-id-lgcookieslaw-purpose="1" disabled="disabled" id="lgcookieslaw_purpose_enabled_1" type="checkbox"/>
# <span class="lgcookieslaw-slider lgcookieslaw-slider-checked"></span>
# <div class="lgcookieslaw-slider-option-right">Taip</div>
# </label>
# </div>
# <div class="lgcookieslaw-section-description">
# <div aria-controls="multi_collapse_lgwhatsapp_purpose_1" aria-expanded="false" class="lgcookieslaw-section-description-button card-header collapsed" data-toggle="collapse" href="#multi_collapse_lgwhatsapp_purpose_1" role="button">
# <span class="card-title">Aprašymas</span>
# </div>
# <div class="lgcookieslaw-section-description-content collapse multi-collapse" id="multi_collapse_lgwhatsapp_purpose_1">
# <p>Functional cookies are strictly necessary to provide the services of the shop, as well as for its proper functioning, so it is not possible to refuse their use. They allow the user to browse through our website and use the different options or services that exist on it.</p> </div>
# </div>
# </div>
# <div class="lgcookieslaw-section">
# <div class="lgcookieslaw-section-name">
#                         Advertising Cookies                    </div>
# <div class="lgcookieslaw-section-checkbox">
# <label class="lgcookieslaw-switch">
# <div class="lgcookieslaw-slider-option-left">Ne</div>
# <input class="lgcookieslaw-purpose-enabled" data-id-lgcookieslaw-purpose="2" id="lgcookieslaw_purpose_enabled_2" type="checkbox"/>
# <span class="lgcookieslaw-slider"></span>
# <div class="lgcookieslaw-slider-option-right">Taip</div>
# </label>
# </div>
# <div class="lgcookieslaw-section-description">
# <div aria-controls="multi_collapse_lgwhatsapp_purpose_2" aria-expanded="false" class="lgcookieslaw-section-description-button card-header collapsed" data-toggle="collapse" href="#multi_collapse_lgwhatsapp_purpose_2" role="button">
# <span class="card-title">Aprašymas</span>
# </div>
# <div class="lgcookieslaw-section-description-content collapse multi-collapse" id="multi_collapse_lgwhatsapp_purpose_2">
# <p>These are cookies that collect information about the advertisements shown to users of the website. They can be anonymous, if they only collect information about the advertising spaces shown without identifying the user, or personalised, if they collect personal information about the user of the shop by a third party, for the personalisation of these advertising spaces.</p> </div>
# </div>
# </div>
# <div class="lgcookieslaw-section">
# <div class="lgcookieslaw-section-name">
#                         Analytics cookies                    </div>
# <div class="lgcookieslaw-section-checkbox">
# <label class="lgcookieslaw-switch">
# <div class="lgcookieslaw-slider-option-left">Ne</div>
# <input class="lgcookieslaw-purpose-enabled lgcookieslaw-analytics-purpose" data-id-lgcookieslaw-purpose="3" id="lgcookieslaw_purpose_enabled_3" type="checkbox"/>
# <span class="lgcookieslaw-slider"></span>
# <div class="lgcookieslaw-slider-option-right">Taip</div>
# </label>
# </div>
# <div class="lgcookieslaw-section-description">
# <div aria-controls="multi_collapse_lgwhatsapp_purpose_3" aria-expanded="false" class="lgcookieslaw-section-description-button card-header collapsed" data-toggle="collapse" href="#multi_collapse_lgwhatsapp_purpose_3" role="button">
# <span class="card-title">Aprašymas</span>
# </div>
# <div class="lgcookieslaw-section-description-content collapse multi-collapse" id="multi_collapse_lgwhatsapp_purpose_3">
# <p>Collect information about the user's browsing experience in the shop, usually anonymously, although sometimes they also allow the user to be uniquely and unequivocally identified in order to obtain reports on the user's interests in the products or services offered by the shop.</p> </div>
# </div>
# </div>
# <div class="lgcookieslaw-section">
# <div class="lgcookieslaw-section-name">
#                         Performance cookies                    </div>
# <div class="lgcookieslaw-section-checkbox">
# <label class="lgcookieslaw-switch">
# <div class="lgcookieslaw-slider-option-left">Ne</div>
# <input class="lgcookieslaw-purpose-enabled" data-id-lgcookieslaw-purpose="4" id="lgcookieslaw_purpose_enabled_4" type="checkbox"/>
# <span class="lgcookieslaw-slider"></span>
# <div class="lgcookieslaw-slider-option-right">Taip</div>
# </label>
# </div>
# <div class="lgcookieslaw-section-description">
# <div aria-controls="multi_collapse_lgwhatsapp_purpose_4" aria-expanded="false" class="lgcookieslaw-section-description-button card-header collapsed" data-toggle="collapse" href="#multi_collapse_lgwhatsapp_purpose_4" role="button">
# <span class="card-title">Aprašymas</span>
# </div>
# <div class="lgcookieslaw-section-description-content collapse multi-collapse" id="multi_collapse_lgwhatsapp_purpose_4">
# <p>These are used to improve the browsing experience and optimise the operation of the shop.</p> </div>
# </div>
# </div>
# <div class="lgcookieslaw-section">
# <div class="lgcookieslaw-section-name">
#                         Other cookies                    </div>
# <div class="lgcookieslaw-section-checkbox">
# <label class="lgcookieslaw-switch">
# <div class="lgcookieslaw-slider-option-left">Ne</div>
# <input class="lgcookieslaw-purpose-enabled" data-id-lgcookieslaw-purpose="5" id="lgcookieslaw_purpose_enabled_5" type="checkbox"/>
# <span class="lgcookieslaw-slider"></span>
# <div class="lgcookieslaw-slider-option-right">Taip</div>
# </label>
# </div>
# <div class="lgcookieslaw-section-description">
# <div aria-controls="multi_collapse_lgwhatsapp_purpose_5" aria-expanded="false" class="lgcookieslaw-section-description-button card-header collapsed" data-toggle="collapse" href="#multi_collapse_lgwhatsapp_purpose_5" role="button">
# <span class="card-title">Aprašymas</span>
# </div>
# <div class="lgcookieslaw-section-description-content collapse multi-collapse" id="multi_collapse_lgwhatsapp_purpose_5">
# <p>These are cookies without a clear purpose or those that we are still in the process of classifying.</p> </div>
# </div>
# </div>
# </div>
# <div class="lgcookieslaw-modal-footer">
# <div class="lgcookieslaw-modal-footer-left">
# <button class="btn lgcookieslaw-cancel" id="lgcookieslaw_cancel"> &gt; Atšaukti</button>
# </div>
# <div class="lgcookieslaw-modal-footer-right">
# <button class="btn lgcookieslaw-reject-all" id="lgcookieslaw_reject_all" onclick="closeinfo(true, 0)">Atmesti</button>
# <button class="btn lgcookieslaw-save" id="lgcookieslaw_save" onclick="closeinfo(true, 2)">Priimti pasirinkimą</button>
# <button class="btn lgcookieslaw-accept-all lggoogleanalytics-accept" id="lgcookieslaw_accept_all" onclick="closeinfo(true, 1)">Priimti visus</button>
# </div>
# </div>
# </div>
# <div class="lgcookieslaw-overlay"></div>
# </div>
# <div class="row">
# </div>
# <div class="row">
# <div class="col-12">
# <div class="copyright-container text-center mb-3 mt-3">
# <div class="d-flex align-items-center">
#
# 			 1999 - 2023 © UAB "Baltijos arsenalas" parduotuvė "ARMIJAI IR CIVILIAMS"
#
#           </div>
# <table>
# <tr>
# <td><a href="https://keliaukime.lt" style="color: #000000" target="_blank">Pigiausi skrydžiai, kelionės</a></td>
# <td><a href="https://top.hostin.lt/index.php?a=stats&amp;u=aic" target="blank"><img alt="Top.HostIN.lt :: Lankomumo skaitiklis, statistika, projektų TOP`as!" border="0" height="31" src="https://top.hostin.lt/button.php?u=aic" width="88"/></a>  <a href="http://www.hey.lt/details.php?id=arsenal" target="_blank"><img border="0" height="31" src="https://www.hey.lt/count.php?id=arsenal" width="88"/></a></td>
# <td><a href="https://kalnuklubas.lt" style="color: #000000" target="_blank">Kalnų kelionių klubas</a></td>
# </tr>
# </table>
# <div class="social-sharing">
# <a class="text-hide mb-2 social-share-btn social-share-btn--footer facebook" href="https://www.facebook.com/AIC.lt/" rel="nofollow noopener" target="_blank">Facebook</a>
# <a class="text-hide mb-2 social-share-btn social-share-btn--footer youtube" href="https://www.youtube.com/channel/UCRobC6EZ8mrJZV3VtcsQUlw/videos" rel="nofollow noopener" target="_blank">YouTube</a>
# <a class="text-hide mb-2 social-share-btn social-share-btn--footer instagram" href="https://www.instagram.com/armijaiirciviliams/?hl=en" rel="nofollow noopener" target="_blank">Instagram</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# </main>
# <div class="modal fade" data-modal-hide-mobile="" id="offcanvas_search_filter" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-dialog__offcanvas modal-dialog__offcanvas--right" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Uždaryti" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body">
# <div id="_mobile_search_filters_wrapper"></div>
# </div>
# <div class="modal-footer">
# <button aria-label="Uždaryti" class="btn_close-filter btn btn-outline-success btn-block ok" data-dismiss="modal">
# <i class="material-icons rtl-no-flip"></i>
#                         Gerai
#                     </button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" data-modal-hide-mobile="" id="mobile_top_menu_wrapper" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-dialog__offcanvas" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <div>
# <a class="header__logo header-top__col" href="https://www.aic.lt/">
# <img alt="ARMIJAI IR CIVILIAMS" class="logo img-fluid" src="https://www.aic.lt/img/logo-16684396091.jpg"/>
# </a>
# </div>
# <button aria-label="Uždaryti" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body">
# <div class="js-top-menu top-menu-mobile" id="_mobile_top_menu"></div>
# <div class="js-top-menu-bottom">
# <div id="_mobile_currency_selector"></div>
# <div id="_mobile_contact_link"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script src="https://www.aic.lt/themes/classic-rocket/assets/cache/bottom-feb59595.js" type="text/javascript"></script>
# <script>(function(){var js = "window['__CF$cv$params']={r:'81c0e8b3fe463685',t:'MTY5ODMwNDUzNi4zNDMwMDA='};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();</script></body>
# </html>

# %%
aic_sales_page.select('#products')
# Out:
# [<section id="products">
#  <div>
#  <div class="row products-selection my-3" id="js-product-list-top">
#  <div class="col-lg-6 visible--desktop total-products">
#  <p class="product__quantity">Yra 187 produktai</p>
#  </div>
#  <div class="col-lg-6">
#  <div class="sort-by-row justify-content-md-end">
#  <div class="form-inline">
#  <div class="form-group mb-0">
#  <label class="visible--desktop" for="select-sort-order">Rikiuoti pagal:</label>
#  <select class="custom-select ml-sm-2" id="select-sort-order">
#  <option value="https://www.aic.lt/ispardavimas?order=product.position.asc">Numatytasis rūšiavimas</option>
#  <option value="https://www.aic.lt/ispardavimas?order=product.date_add.desc">Naujausios prekės</option>
#  <option value="https://www.aic.lt/ispardavimas?order=product.name.asc">Pavadinimas, nuo A iki Z</option>
#  <option value="https://www.aic.lt/ispardavimas?order=product.name.desc">Pavadinimas, nuo Z iki A</option>
#  <option selected="selected" value="https://www.aic.lt/ispardavimas?order=product.price.asc">Žemiausia kaina</option>
#  <option value="https://www.aic.lt/ispardavimas?order=product.price.desc">Aukščiausia kaina</option>
#  <option value="https://www.aic.lt/ispardavimas?order=product.quantity.desc">Turime vietoje</option>
#  </select>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="visible--mobile text-sm-center mt-1 col-12">
#          Rodoma 1-60 iš 187 prekės(-ių)
#      </div>
#  </div>
#  </div>
#  <div class="visible--desktop">
#  </div>
#  <div>
#  <div id="js-product-list">
#  <div class="products">
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="1166" data-id-product-attribute="0">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/sublimuotas-maistas/1166-meatmakers-tactical-original-pork-jerky-vytinta-kiauliena-477902797209.html">
#  <img alt="MeatMakers Tactical Original Pork Jerky (vytinta kiauliena)" class="lazyload" data-full-size-image-url="https://www.aic.lt/6156-large_default/meatmakers-tactical-original-pork-jerky-vytinta-kiauliena.jpg" data-src="https://www.aic.lt/6156-medium_default/meatmakers-tactical-original-pork-jerky-vytinta-kiauliena.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/sublimuotas-maistas/1166-meatmakers-tactical-original-pork-jerky-vytinta-kiauliena-477902797209.html">MeatMakers Tactical Original Pork Jerky (vytinta kiauliena)</a></h2>
#  <div>
#  <div class="text-left mb-1">032566</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">2,50 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">1,50 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag discount">-1,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/sublimuotas-maistas/1166-meatmakers-tactical-original-pork-jerky-vytinta-kiauliena-477902797209.html">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="7678" data-id-product-attribute="0">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/ivairus-laikikliai-karabinai/7678-nite-ize-tvirtinimas-gear-tie-6-juoda-094664018037.html">
#  <img alt="NITE-IZE tvirtinimas Gear..." class="lazyload" data-full-size-image-url="https://www.aic.lt/18772-large_default/nite-ize-tvirtinimas-gear-tie-6-juoda.jpg" data-src="https://www.aic.lt/18772-medium_default/nite-ize-tvirtinimas-gear-tie-6-juoda.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/ivairus-laikikliai-karabinai/7678-nite-ize-tvirtinimas-gear-tie-6-juoda-094664018037.html">NITE-IZE tvirtinimas Gear Tie 6' (juoda)</a></h2>
#  <div>
#  <div class="text-left mb-1">034820</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">4,50 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">2,50 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag discount">-2,00 €</li>
#  <li class="product-flag new">Nauja prekė</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/ivairus-laikikliai-karabinai/7678-nite-ize-tvirtinimas-gear-tie-6-juoda-094664018037.html">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="1514" data-id-product-attribute="0">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/isgyvenimo-reikmenys/1514-hipotermine-antklode-rothco-613902103207.html">
#  <img alt="Hipoterminė išgyvenimo antklodė Rothco" class="lazyload" data-full-size-image-url="https://www.aic.lt/6587-large_default/hipotermine-antklode-rothco.jpg" data-src="https://www.aic.lt/6587-medium_default/hipotermine-antklode-rothco.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/isgyvenimo-reikmenys/1514-hipotermine-antklode-rothco-613902103207.html">Hipoterminė išgyvenimo antklodė Rothco</a></h2>
#  <div>
#  <div class="text-left mb-1">034006</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">4,00 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">3,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag discount">-1,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/isgyvenimo-reikmenys/1514-hipotermine-antklode-rothco-613902103207.html">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="
jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/virvutes-sagteles/5909-nite-ize-tvirtinimo-virve-camjam-6-ft-094664038790.html">NITE-IZE tvirtinimo virvė CamJam 6 ft.</a></h2>
#  <div>
#  <div class="text-left mb-1">0348576</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">13,50 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">9,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag discount">-4,50 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/virvutes-sagteles/5909-nite-ize-tvirtinimo-virve-camjam-6-ft-094664038790.html">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="2003" data-id-product-attribute="0">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/suvenyrai/2003-nite-ize-irankis-doohickey-ratchet-tool-094664051225.html">
#  <img alt="NITE-IZE įrankis Doohickey..." class="lazyload" data-full-size-image-url="https://www.aic.lt/14375-large_default/nite-ize-irankis-doohickey-ratchet-tool.jpg" data-src="https://www.aic.lt/14375-medium_default/nite-ize-irankis-doohickey-ratchet-tool.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/suvenyrai/2003-nite-ize-irankis-doohickey-ratchet-tool-094664051225.html">NITE-IZE įrankis Doohickey Ratchet Tool</a></h2>
#  <div>
#  <div class="text-left mb-1">034847</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">14,00 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">10,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag discount">-4,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/suvenyrai/2003-nite-ize-irankis-doohickey-ratchet-tool-094664051225.html">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="1980" data-id-product-attribute="0">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/ivairus-laikikliai-karabinai/1980-nite-ize-magnetas-steelie-dash-kit-094664044630.html">
#  <img alt="NITE-IZE magnetas Steelie Orbiter magnetic socket and metal plate" class="lazyload" data-full-size-image-url="https://www.aic.lt/7171-large_default/nite-ize-magnetas-steelie-dash-kit.jpg" data-src="https://www.aic.lt/7171-medium_default/nite-ize-magnetas-steelie-dash-kit.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/ivairus-laikikliai-karabinai/1980-nite-ize-magnetas-steelie-dash-kit-094664044630.html">NITE-IZE magnetas Steelie Orbiter magnetic socket and metal plate</a></h2>
#  <div>
#  <div class="text-left mb-1">034805</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">17,00 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">10,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag discount">-7,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/ivairus-laikikliai-karabinai/1980-nite-ize-magnetas-steelie-dash-kit-094664044630.html">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="5910" data-id-product-attribute="0">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/virvutes-sagteles/5910-nite-ize-tvirtinimo-virve-camjam-12-ft-094664038776.html">
#  <img alt="NITE-IZE tvirtinimo virvė..." class="lazyload" data-full-size-image-url="https://www.aic.lt/13583-large_default/nite-ize-tvirtinimo-virve-camjam-12-ft.jpg" data-src="https://www.aic.lt/13583-medium_default/nite-ize-tvirtinimo-virve-camjam-12-ft.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/virvutes-sagteles/5910-nite-ize-tvirtinimo-virve-camjam-12-ft-094664038776.html">NITE-IZE tvirtinimo virvė CamJam 12 ft.</a></h2>
#  <div>
#  <div class="text-left mb-1">0348577</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">15,00 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">10,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag discount">-5,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/virvutes-sagteles/5910-nite-ize-tvirtinimo-virve-camjam-12-ft-094664038776.html">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="607" data-id-product-attribute="1438">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/taktines-pirstines/607-1438-pirstines-arsenal-pilot-nomex-7dyds.html#/71-rivile_select_attributes-08">
#  <img alt="Pirštinės ARSENAL Pilot (Nomex)" class="lazyload" data-full-size-image-url="https://www.aic.lt/5247-large_default/pirstines-arsenal-pilot-nomex-7dyds.jpg" data-src="https://www.aic.lt/5247-medium_default/pirstines-arsenal-pilot-nomex-7dyds.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/taktines-pirstines/607-1438-pirstines-arsenal-pilot-nomex-7dyds.html#/71-rivile_select_attributes-08">Pirštinės ARSENAL Pilot (Nomex)</a></h2>
#  <div>
#  <div class="text-left mb-1">017008</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">22,00 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">11,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag on-sale">Išpardavimas!</li>
#  <li class="product-flag discount">-11,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/taktines-pirstines/607-1438-pirstines-arsenal-pilot-nomex-7dyds.html#/71-rivile_select_attributes-08">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="3022" data-id-product-attribute="0">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/neperslampami-maisai-ir-deklai/3022-aloksak-mais-2vnt-alokd2-6x6-1619-x-1334cm-757791026602.html">
#  <img alt="ALOKSAK maišeliai 2vnt 16x16cm (ALOK2-6x6)" class="lazyload" data-full-size-image-url="https://www.aic.lt/8890-large_default/aloksak-mais-2vnt-alokd2-6x6-1619-x-1334cm.jpg" data-src="https://www.aic.lt/8890-medium_default/aloksak-mais-2vnt-alokd2-6x6-1619-x-1334cm.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/neperslampami-maisai-ir-deklai/3022-aloksak-mais-2vnt-alokd2-6x6-1619-x-1334cm-757791026602.html">ALOKSAK maišeliai 2vnt 16x16cm (ALOK2-6x6)</a></h2>
#  <div>
#  <div class="text-left mb-1">044225</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">13,50 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">6,50 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag discount">-7,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/neperslampami-maisai-ir-deklai/3022-aloksak-mais-2vnt-alokd2-6x6-1619-x-1334cm-757791026602.html">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="5911" data-id-product-attribute="0">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/virvutes-sagteles/5911-nite-ize-tvirtinimo-virve-camjam-18-ft-094664038783.html">
#  <img alt="NITE-IZE tvirtinimo virvė..." class="lazyload" data-full-size-image-url="https://www.aic.lt/13581-large_default/nite-ize-tvirtinimo-virve-camjam-18-ft.jpg" data-src="https://www.aic.lt/13581-medium_default/nite-ize-tvirtinimo-virve-camjam-18-ft.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/virvutes-sagteles/5911-nite-ize-tvirtinimo-virve-camjam-18-ft-094664038783.html">NITE-IZE tvirtinimo virvė CamJam 18 ft.</a></h2>
#  <div>
#  <div class="text-left mb-1">0348579</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">18,50 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">14,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag discount">-4,50 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/virvutes-sagteles/5911-nite-ize-tvirtinimo-virve-camjam-18-ft-094664038783.html">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="3028" data-id-product-attribute="0">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/neperslampami-maisai-ir-deklai/3028-opsak-mais-2vnt-eu-opd2-7x7-171-x-178cm-757791200774.html">
#  <img alt="OPSAK maišeliai 2vnt (EU-OPD2-7x7) 17.1 x 17.8cm" class="lazyload" data-full-size-image-url="https://www.aic.lt/8901-large_default/opsak-mais-2vnt-eu-opd2-7x7-171-x-178cm.jpg" data-src="https://www.aic.lt/8901-medium_default/opsak-mais-2vnt-eu-opd2-7x7-171-x-178cm.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/neperslampami-maisai-ir-deklai/3028-opsak-mais-2vnt-eu-opd2-7x7-171-x-178cm-757791200774.html">OPSAK maišeliai 2vnt (EU-OPD2-7x7) 17.1 x 17.8cm</a></h2>
#  <div>
#  <div class="text-left mb-1">044255</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">14,00 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">7,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag discount">-7,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/neperslampami-maisai-ir-deklai/3028-opsak-mais-2vnt-eu-opd2-7x7-171-x-178cm-757791200774.html">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="2475" data-id-product-attribute="0">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/maisto-virykles/2475-nesiojamas-grilius-36x46x30-599956364383.html">
#  <img alt="Nešiojamas grilius 36x46x30" class="lazyload" data-full-size-image-url="https://www.aic.lt/791-large_default/nesiojamas-grilius-36x46x30.jpg" data-src="https://www.aic.lt/791-medium_default/nesiojamas-grilius-36x46x30.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/maisto-virykles/2475-nesiojamas-grilius-36x46x30-599956364383.html">Nešiojamas grilius 36x46x30</a></h2>
#  <div>
#  <div class="text-left mb-1">036307</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">20,00 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">15,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag discount">-5,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/maisto-virykles/2475-nesiojamas-grilius-36x46x30-599956364383.html">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="4408" data-id-product-attribute="7064">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/511-marskineliai/4408-7064-marskineliai-511-pt-r-always-ranger-green-888579505917.html#/13-rivile_select_attributes-xxl">
#  <img alt="Marškinėliai 5.11 PT-R..." class="lazyload" data-full-size-image-url="https://www.aic.lt/13416-large_default/marskineliai-511-pt-r-always-ranger-green.jpg" data-src="https://www.aic.lt/13416-medium_default/marskineliai-511-pt-r-always-ranger-green.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/511-marskineliai/4408-7064-marskineliai-511-pt-r-always-ranger-green-888579505917.html#/13-rivile_select_attributes-xxl">Marškinėliai 5.11 PT-R Always, ranger green</a></h2>
#  <div>
#  <div class="text-left mb-1">5-82129-186</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">25,00 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">15,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag on-sale">Išpardavimas!</li>
#  <li class="product-flag discount">-10,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/511-marskineliai/4408-7064-marskineliai-511-pt-r-always-ranger-green-888579505917.html#/13-rivile_select_attributes-xxl">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="2007" data-id-product-attribute="0">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/
jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
# ...
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/kelnes/519-9727-kelnes-helikon-sfu-next-rip-stop-juoda-3xlr.html#/48-rivile_select_attributes-lr">Kelnės Helikon SFU Rip-stop (juoda)</a></h2>
#  <div>
#  <div class="text-left mb-1">016076</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">45,00 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">33,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag on-sale">Išpardavimas!</li>
#  <li class="product-flag discount">-12,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/kelnes/519-9727-kelnes-helikon-sfu-next-rip-stop-juoda-3xlr.html#/48-rivile_select_attributes-lr">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="5159" data-id-product-attribute="9333">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/511-marskineliai/5159-9333-marskineliai-il-ra-511-pt-r-charge-python-888579502916.html#/10-rivile_select_attributes-m">
#  <img alt="Marškinėliai il/ra 5.11..." class="lazyload" data-full-size-image-url="https://www.aic.lt/11519-large_default/marskineliai-il-ra-511-pt-r-charge-python.jpg" data-src="https://www.aic.lt/11519-medium_default/marskineliai-il-ra-511-pt-r-charge-python.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/511-marskineliai/5159-9333-marskineliai-il-ra-511-pt-r-charge-python-888579502916.html#/10-rivile_select_attributes-m">Marškinėliai il/ra 5.11 PT-R Charge, python</a></h2>
#  <div>
#  <div class="text-left mb-1">5-82136-256</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">49,00 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">35,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag on-sale">Išpardavimas!</li>
#  <li class="product-flag discount">-14,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/511-marskineliai/5159-9333-marskineliai-il-ra-511-pt-r-charge-python-888579502916.html#/10-rivile_select_attributes-m">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="6240" data-id-product-attribute="12515">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/511-marskiniai/6240-12515-marskiniai-tr-ra-511-wyatt-black-888579529111.html#/10-rivile_select_attributes-m">
#  <img alt="Marškiniai tr/ra 5.11..." class="lazyload" data-full-size-image-url="https://www.aic.lt/15467-large_default/marskiniai-tr-ra-511-wyatt-black.jpg" data-src="https://www.aic.lt/15467-medium_default/marskiniai-tr-ra-511-wyatt-black.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/511-marskiniai/6240-12515-marskiniai-tr-ra-511-wyatt-black-888579529111.html#/10-rivile_select_attributes-m">Marškiniai tr/ra 5.11 WYATT, black</a></h2>
#  <div>
#  <div class="text-left mb-1">5-71204-668</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">45,00 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">35,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag on-sale">Išpardavimas!</li>
#  <li class="product-flag discount">-10,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/511-marskiniai/6240-12515-marskiniai-tr-ra-511-wyatt-black-888579529111.html#/10-rivile_select_attributes-m">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="6241" data-id-product-attribute="12520">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/511-marskiniai/6241-12520-marskiniai-tr-ra-511-wyatt-grey-888579529173.html#/11-rivile_select_attributes-s">
#  <img alt="Marškiniai tr/ra 5.11..." class="lazyload" data-full-size-image-url="https://www.aic.lt/15457-large_default/marskiniai-tr-ra-511-wyatt-grey.jpg" data-src="https://www.aic.lt/15457-medium_default/marskiniai-tr-ra-511-wyatt-grey.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/511-marskiniai/6241-12520-marskiniai-tr-ra-511-wyatt-grey-888579529173.html#/11-rivile_select_attributes-s">Marškiniai tr/ra 5.11 WYATT, grey</a></h2>
#  <div>
#  <div class="text-left mb-1">5-71204-674</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">45,00 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">35,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag on-sale">Išpardavimas!</li>
#  <li class="product-flag discount">-10,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/511-marskiniai/6241-12520-marskiniai-tr-ra-511-wyatt-grey-888579529173.html#/11-rivile_select_attributes-s">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="3050" data-id-product-attribute="0">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/ginklu-valymo-reikmenys/3050-btc-valymo-komplektas-ar10-03cal-854325008001.html">
#  <img alt="BTC valymo komplektas AR10/0.3Cal" class="lazyload" data-full-size-image-url="https://www.aic.lt/8923-large_default/btc-valymo-komplektas-ar10-03cal.jpg" data-src="https://www.aic.lt/8923-medium_default/btc-valymo-komplektas-ar10-03cal.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/ginklu-valymo-reikmenys/3050-btc-valymo-komplektas-ar10-03cal-854325008001.html">BTC valymo komplektas AR10/0.3Cal</a></h2>
#  <div>
#  <div class="text-left mb-1">044331</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">47,00 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">35,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag discount">-12,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/ginklu-valymo-reikmenys/3050-btc-valymo-komplektas-ar10-03cal-854325008001.html">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="4213" data-id-product-attribute="4644">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/511-marskiniai/4213-4644-marskiniai-tr-ra-511-wyatt-plaid-blue-888579466942.html#/11-rivile_select_attributes-s">
#  <img alt="Marškiniai 5.11 Wyatt Plaid, blue" class="lazyload" data-full-size-image-url="https://www.aic.lt/11001-large_default/marskiniai-tr-ra-511-wyatt-plaid-blue.jpg" data-src="https://www.aic.lt/11001-medium_default/marskiniai-tr-ra-511-wyatt-plaid-blue.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/511-marskiniai/4213-4644-marskiniai-tr-ra-511-wyatt-plaid-blue-888579466942.html#/11-rivile_select_attributes-s">Marškiniai 5.11 Wyatt Plaid, blue</a></h2>
#  <div>
#  <div class="text-left mb-1">5-71204-710</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">45,00 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">35,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag on-sale">Išpardavimas!</li>
#  <li class="product-flag discount">-10,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/511-marskiniai/4213-4644-marskiniai-tr-ra-511-wyatt-plaid-blue-888579466942.html#/11-rivile_select_attributes-s">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="5158" data-id-product-attribute="9327">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/511-marskineliai/5158-9327-marskineliai-il-ra-511-pt-r-charge-juoda-888579502862.html#/9-rivile_select_attributes-l">
#  <img alt="Marškinėliai il/ra 5.11..." class="lazyload" data-full-size-image-url="https://www.aic.lt/11522-large_default/marskineliai-il-ra-511-pt-r-charge-juoda.jpg" data-src="https://www.aic.lt/11522-medium_default/marskineliai-il-ra-511-pt-r-charge-juoda.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/511-marskineliai/5158-9327-marskineliai-il-ra-511-pt-r-charge-juoda-888579502862.html#/9-rivile_select_attributes-l">Marškinėliai il/ra 5.11 PT-R Charge, juoda</a></h2>
#  <div>
#  <div class="text-left mb-1">5-82136-019</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">49,00 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">35,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag on-sale">Išpardavimas!</li>
#  <li class="product-flag discount">-14,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/511-marskineliai/5158-9327-marskineliai-il-ra-511-pt-r-charge-juoda-888579502862.html#/9-rivile_select_attributes-l">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  <article class="product-miniature js-product-miniature mb-3" data-id-product="7484" data-id-product-attribute="14656">
#  <div class="card card-product">
#  <div class="card-img-top product__card-img">
#  <a class="thumbnail product-thumbnail rc ratio1_1" href="https://www.aic.lt/511-marskineliai/7484-14656-marskineliai-il-ra-511-pt-r-charge-heather-888579584370.html#/10-rivile_select_attributes-m">
#  <img alt="Marškinėliai il/ra 5.11..." class="lazyload" data-full-size-image-url="https://www.aic.lt/17552-large_default/marskineliai-il-ra-511-pt-r-charge-heather.jpg" data-src="https://www.aic.lt/17552-medium_default/marskineliai-il-ra-511-pt-r-charge-heather.jpg"/>
#  </a>
#  <div class="highlighted-informations text-center p-2 no-variants visible--desktop">
#  <span class="quick-view" data-link-action="quickview">
#  <i class="material-icons search"></i> Greita peržiūra
#                    </span>
#  </div>
#  </div>
#  <div class="card-body">
#  <div class="product-description product__card-desc">
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/511-marskineliai/7484-14656-marskineliai-il-ra-511-pt-r-charge-heather-888579584370.html#/10-rivile_select_attributes-m">Marškinėliai il/ra 5.11 PT-R Charge, heather</a></h2>
#  <div>
#  <div class="text-left mb-1">5-82136-103</div>
#  <div class="d--flex-between">
#  <div class="product-price-and-shipping text-left">
#  <span class="sr-only">Reguliari kaina</span>
#  <span class="regular-price">49,00 €</span>
#  <span class="sr-only">Kaina</span>
#  <span class="price current-price-discount">35,00 €</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul class="product-flags">
#  <li class="product-flag discount">-14,00 €</li>
#  </ul>
#  <a class="product-select" href="https://www.aic.lt/511-marskineliai/7484-14656-marskineliai-il-ra-511-pt-r-charge-heather-888579584370.html#/10-rivile_select_attributes-m">Pasirinkti<i class="material-icons"></i></a>
#  </div>
#  </article>
#  </div>
#  <div class="row u-a-i-c">
#  <div class="small col-lg-4">
#
#        Rodoma 1-60 iš 187 prekės(-ių)
#
#    </div>
#  <nav class="col-lg-8">
#  <ul class="page-list pagination justify-content-center justify-content-lg-end mt-3 mt-lg-0 mb-0">
#  <li class="page-item active">
#  <a class="page-link disabled js-search-link" href="https://www.aic.lt/ispardavimas" rel="nofollow" tabindex="-1">
#                                        1
#                                    </a>
#  </li>
#  <li class="page-item">
#  <a class="page-link js-search-link" href="https://www.aic.lt/ispardavimas?page=2" rel="nofollow">
#                                        2
#                                    </a>
#  </li>
#  <li class="page-item">
#  <a class="page-link js-search-link" href="https://www.aic.lt/ispardavimas?page=3" rel="nofollow">
#                                        3
#                                    </a>
#  </li>
#  <li class="page-item">
#  <a class="page-link js-search-link" href="https://www.aic.lt/ispardavimas?page=4" rel="nofollow">
#                                        4
#                                    </a>
#  </li>
#  <li class="page-item">
#  <a class="page-link next js-search-link" href="https://www.aic.lt/ispardavimas?page=2" rel="next">
#  <span class="sr-only">Kitas</span><i aria-hidden="true" class="material-icons"></i>
#  </a>
#  </li>
#  </ul>
#  </nav>
#  </div>
#  <div class="visible--mobile text-right up">
#  <a class="btn btn-secondary" href="#header">
#        Atgal į viršų
#        <i class="material-icons"></i>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div id="js-product-list-bottom">
#  <div id="js-product-list-bottom"></div>
#  </div>
#  </section>]

# %%
products = aic_sales_page.select('#products h2')
products
# Out:
# [<h2 class="h3 product-title text-left"><a href="https://www.aic.lt/sublimuotas-maistas/1166-meatmakers-tactical-original-pork-jerky-vytinta-kiauliena-477902797209.html">MeatMakers Tactical Original Pork Jerky (vytinta kiauliena)</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/ivairus-laikikliai-karabinai/7678-nite-ize-tvirtinimas-gear-tie-6-juoda-094664018037.html">NITE-IZE tvirtinimas Gear Tie 6' (juoda)</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/isgyvenimo-reikmenys/1514-hipotermine-antklode-rothco-613902103207.html">Hipoterminė išgyvenimo antklodė Rothco</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/ivairus-laikikliai-karabinai/1997-nite-ize-plastik-karabinas-sbp6-juoda-094664019263.html">NITE-IZE plastik. karabinas SBP6 (juoda)</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/ivairus-laikikliai-karabinai/1983-nite-ize-tvirtinimas-gear-tie-12-juoda-094664019669.html">NITE-IZE tvirtinimas Gear Tie 12' (juoda) 2 vnt</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/ivairus-laikikliai-karabinai/1984-nite-ize-tvirtinimas-gear-tie-18-juoda-094664018198.html">NITE-IZE tvirtinimas Gear Tie 18' (juoda) 2 vnt</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/k
</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/kelnes/523-9750-kelnes-helikon-sfu-next-rip-stop-zalia-ll.html#/48-rivile_select_attributes-lr">Kelnės SFU Rip-Stop (žalia)</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/kelnes/521-9740-kelnes-helikon-sfu-next-rip-stop-camo-lr.html#/49-rivile_select_attributes-mr">Kelnės SFU Next Rip-stop (woodland)</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/511-moteriska-apranga/4196-4560-moteriski-marskineliai-il-ra-511-pt-r-sage-888579504309.html#/9-rivile_select_attributes-l">Moteriški marškinėliai il/ra 5.11 PT-R, sage</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/511-moteriska-apranga/4197-4564-motsortai-511-pt-r-eliza-green-camo-888579501346.html#/9-rivile_select_attributes-l">Moteriški šortai 5.11 PT-R Eliza, green camo</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/kelnes/519-9727-kelnes-helikon-sfu-next-rip-stop-juoda-3xlr.html#/48-rivile_select_attributes-lr">Kelnės Helikon SFU Rip-stop (juoda)</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/511-marskineliai/5159-9333-marskineliai-il-ra-511-pt-r-charge-python-888579502916.html#/10-rivile_select_attributes-m">Marškinėliai il/ra 5.11 PT-R Charge, python</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/511-marskiniai/6240-12515-marskiniai-tr-ra-511-wyatt-black-888579529111.html#/10-rivile_select_attributes-m">Marškiniai tr/ra 5.11 WYATT, black</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/511-marskiniai/6241-12520-marskiniai-tr-ra-511-wyatt-grey-888579529173.html#/11-rivile_select_attributes-s">Marškiniai tr/ra 5.11 WYATT, grey</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/ginklu-valymo-reikmenys/3050-btc-valymo-komplektas-ar10-03cal-854325008001.html">BTC valymo komplektas AR10/0.3Cal</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/511-marskiniai/4213-4644-marskiniai-tr-ra-511-wyatt-plaid-blue-888579466942.html#/11-rivile_select_attributes-s">Marškiniai 5.11 Wyatt Plaid, blue</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/511-marskineliai/5158-9327-marskineliai-il-ra-511-pt-r-charge-juoda-888579502862.html#/9-rivile_select_attributes-l">Marškinėliai il/ra 5.11 PT-R Charge, juoda</a></h2>,
#  <h2 class="h3 product-title text-left"><a href="https://www.aic.lt/511-marskineliai/7484-14656-marskineliai-il-ra-511-pt-r-charge-heather-888579584370.html#/10-rivile_select_attributes-m">Marškinėliai il/ra 5.11 PT-R Charge, heather</a></h2>]

# %%
for product in products:
    kaina = product.find_next(class_='price')
    print(kaina.get_text(), product.get_text())
# Out:
# 1,50 € MeatMakers Tactical Original Pork Jerky (vytinta kiauliena)
# 2,50 € NITE-IZE tvirtinimas Gear Tie 6' (juoda)
# 3,00 € Hipoterminė išgyvenimo antklodė Rothco
# 3,50 € NITE-IZE plastik. karabinas SBP6 (juoda)
# 3,50 € NITE-IZE tvirtinimas Gear Tie 12' (juoda) 2 vnt
# 4,00 € NITE-IZE tvirtinimas Gear Tie 18' (juoda) 2 vnt
# 5,50 € Rankšluostis JR GEAR Quick Dry, L-XL, Baltic (mėlyna)
# 14,00 € Rankšluostis JR GEAR Quick Dry, L-XL, Beetle (žalia)
# 6,00 € Krepšelis TT Dump Pouch Light (juoda)
# 6,00 € NITE-IZE tel. dėklas CashBack Wallet
# 4,50 € ALOKSAK maišeliai 2vnt.13x12cm (ALOK2-5x4)
# 9,00 € NITE-IZE tvirtinimo virvė CamJam 6 ft.
